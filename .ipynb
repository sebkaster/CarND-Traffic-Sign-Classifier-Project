# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Traffic Sign Recognition Classifier

# %% [markdown]
# The steps of this project are the following:
# * Load the data set
# * Explore, summarize and visualize the data set
# * Perform preprocessing and data augmentation
# * Design, train and test a model architecture
# * Use the model to make predictions on new images
# * Analyze the softmax probabilities of the new images

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %% [markdown]
# ### Load Data Set

# %% [markdown]
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**

# %%
# Load pickled data
import pickle
import copy

data_folder = 'traffic-signs-data/'
training_file = data_folder + 'test.p'
validation_file= data_folder + 'valid.p'
testing_file = data_folder + 'train.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ### Load Class ID Traffic Sign Mapping

# %%
import csv

sign_id_dict = {}
with open('signnames.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            line_count += 1
        else:
            sign_id_dict[row[0]] = row[1]
            line_count += 1
    print(f'Processed {line_count} lines.')
                  
print(sign_id_dict)
# Out:
# Processed 44 lines.
# {'0': 'Speed limit (20km/h)', '1': 'Speed limit (30km/h)', '2': 'Speed limit (50km/h)', '3': 'Speed limit (60km/h)', '4': 'Speed limit (70km/h)', '5': 'Speed limit (80km/h)', '6': 'End of speed limit (80km/h)', '7': 'Speed limit (100km/h)', '8': 'Speed limit (120km/h)', '9': 'No passing', '10': 'No passing for vehicles over 3.5 metric tons', '11': 'Right-of-way at the next intersection', '12': 'Priority road', '13': 'Yield', '14': 'Stop', '15': 'No vehicles', '16': 'Vehicles over 3.5 metric tons prohibited', '17': 'No entry', '18': 'General caution', '19': 'Dangerous curve to the left', '20': 'Dangerous curve to the right', '21': 'Double curve', '22': 'Bumpy road', '23': 'Slippery road', '24': 'Road narrows on the right', '25': 'Road work', '26': 'Traffic signals', '27': 'Pedestrians', '28': 'Children crossing', '29': 'Bicycles crossing', '30': 'Beware of ice/snow', '31': 'Wild animals crossing', '32': 'End of all speed and passing limits', '33': 'Turn right ahead', '34': 'Turn left ahead', '35': 'Ahead only', '36': 'Go straight or right', '37': 'Go straight or left', '38': 'Keep right', '39': 'Keep left', '40': 'Roundabout mandatory', '41': 'End of no passing', '42': 'End of no passing by vehicles over 3.5 metric tons'}

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration

# %% [markdown]
# ### Basic Summary of the Data Set

# %%
import numpy as np

### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results

# Number of training examples
n_train = len(X_train)

# Number of validation examples
n_validation = len(X_valid)

# Number of testing examples.
n_test = len(X_test)

# What's the shape of an traffic sign image?
image_shape = X_train[0].shape

# How many unique classes/labels there are in the dataset.
n_classes = len(np.unique(y_train))

print("Number of training examples =", n_train)
print("Number of validation examples =", n_validation)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 12630
# Number of validation examples = 4410
# Number of testing examples = 34799
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset.

# %%
### Data exploration visualization code goes here.
import matplotlib.pyplot as plt
from random import randint
# Visualizations will be shown in the notebook.
# %matplotlib inline

for i in range(20):
    index = randint(0, len(X_train))
    img = X_train[index]
    plt.imshow(img)
    plt.show()
    
min_class = np.min(y_train)
max_class = np.max(y_train)

# %%
classes_index = []
classes_distributions = []
i = min_class

class_dict = {}
while i <= max_class:
    num = len([1 for sample in y_train if sample == i])
    class_dict[i] = num
    classes_index.append(i)
    classes_distributions.append(num)
    i += 1

plt.bar(classes_index, classes_distributions, align='center')
plt.ylabel('Classes')
plt.xlabel('No of Samples')
plt.title('Data Visualization')
plt.show()

# %% [markdown]
# ----
#
# ## Step 2: Preprocessing

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %%
import cv2

# %% [markdown]
# ### Histogram Equalization

# %% [markdown]
# Adjust image intensities to enhance contrast.

# %%
def equalize_hist(img_rgb):
    img_yuv = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2YUV)
    img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])
    return cv2.cvtColor(img_yuv, cv2.COLOR_YUV2RGB)

# %%
X_train_temp = []

for img in X_train:
    X_train_temp.append(equalize_hist(img))

X_train = np.array(X_train_temp)

X_valid_temp = []

for img in X_valid:
    X_valid_temp.append(equalize_hist(img))

X_valid = np.array(X_valid_temp)

new_imgs = []
new_img_class = []

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# Increase the diversity of data available for training models, without actually collecting new data.

# %%
def random_brightness(img_rgb):
    img_hsv = cv2.cvtColor(img_rgb,cv2.COLOR_RGB2HSV)
    random_brightness_value = .25+np.random.uniform()
    img_hsv[:,:,2] = img_hsv[:,:,2]*random_brightness_value
    return cv2.cvtColor(img_hsv,cv2.COLOR_HSV2RGB)

# %%
def random_translate(img):
    num_rows, num_cols = img.shape[:2]
    
    pixel_limit = 2
    dx,dy = np.random.randint(-pixel_limit,pixel_limit,2)
    
    translation_matrix = np.float32([ [1,0,dx], [0,1,dy] ])
    return cv2.warpAffine(img, translation_matrix, (num_cols, num_rows))

# %%
def random_scale(img):   
    num_rows, num_cols = img.shape[:2]

    # transform limits
    pixel_limit = np.random.randint(-2,2)

    # ending locations
    pts1 = np.float32([[pixel_limit,pixel_limit],[num_rows-pixel_limit,pixel_limit], \
                       [pixel_limit,num_cols-pixel_limit],[num_rows-pixel_limit,num_cols-pixel_limit]])

    # starting locations (4 corners)
    pts2 = np.float32([[0,0],[num_rows,0],[0,num_cols],[num_rows,num_cols]])

    M = cv2.getPerspectiveTransform(pts1,pts2)
    
    return cv2.warpPerspective(img,M,(num_rows,num_cols))

# %%
def random_rotate(img):
    rows,cols = img.shape[:2]
    angle = np.random.randint(-20, 20) # random angle
    M = cv2.getRotationMatrix2D(((cols-1)/2.0,(rows-1)/2.0),angle,1)
    return cv2.warpAffine(img,M,(cols,rows))

# %%
def random_warp(img):
    
    num_rows, num_cols = img.shape[:2]

    # random scaling coefficients
    rndx = np.random.rand(3) - 0.5
    rndx *= num_cols * 0.06
    rndy = np.random.rand(3) - 0.5
    rndy *= num_rows * 0.06

    # 3 starting points for transform, 1/4 way from edges
    x1 = num_cols/4
    x2 = 3*num_cols/4
    y1 = num_rows/4
    y2 = 3*num_rows/4

    pts1 = np.float32([[y1,x1],
                       [y2,x1],
                       [y1,x2]])
    pts2 = np.float32([[y1+rndy[0],x1+rndx[0]],
                       [y2+rndy[1],x1+rndx[1]],
                       [y1+rndy[2],x2+rndx[2]]])

    M = cv2.getAffineTransform(pts1,pts2)

    return cv2.warpAffine(img,M,(num_cols,num_rows))

# %% [markdown]
# Demonstrate different augmentation functions on one image of the training set.

# %%
plt.imshow(X_train[0])
plt.show()

plt.imshow(random_translate(X_train[0]))
plt.show()

plt.imshow(random_rotate(X_train[0]))
plt.show()

plt.imshow(random_warp(X_train[0]))
plt.show()

plt.imshow(random_scale(X_train[0]))
plt.show()

plt.imshow(random_brightness(X_train[0]))
plt.show()

# %% [markdown]
# Perform data augmentation on images until every class has 3500 data samples.

# %%
added_imgs = True

while(1):
    added_imgs = False
    for img, y_class in zip(X_train, y_train):
        
        if class_dict[y_class] >= 3500:
            continue
            
        size_before = len(new_img_class)
            
        new_imgs.append(random_translate(img))
        new_img_class.append(y_class)
        
        new_imgs.append(random_rotate(img))
        new_img_class.append(y_class)
        
        new_imgs.append(random_warp(img))
        new_img_class.append(y_class)
        
        new_imgs.append(random_scale(img))
        new_img_class.append(y_class)
        
        new_imgs.append(random_brightness(img))
        new_img_class.append(y_class)
        class_dict[y_class] += len(new_img_class) - size_before
        added_imgs = True
    if not added_imgs:
        break
    
X_train = np.concatenate((X_train, new_imgs), axis=0).squeeze()
y_train = np.concatenate((y_train, new_img_class), axis=0).squeeze()

# %% [markdown]
# Plot class distribution. Now every class should have the same number of data samples.

# %%
classes_index = []
classes_distributions = []
i = min_class
while i <= max_class:
    num = len([1 for sample in y_train if sample == i])
    classes_index.append(i)
    classes_distributions.append(num)
    i += 1

plt.bar(classes_index, classes_distributions, align='center')
plt.ylabel('Classes')
plt.xlabel('No of Samples')
plt.title('Data Visualization')
plt.show()

# %% [markdown]
# ### Image Normalization and Greyscale Transformation

# %%
def normalize_data(dataset):
    dataset = np.sum(dataset/3, axis=3, keepdims=True)
    return (dataset - 128)/128

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

X_train_normalized = normalize_data(X_train)
X_valid_normalized = normalize_data(X_valid)

# %% [markdown]
# ---
#
# ## Step 4: Model Architecture

# %%
from tensorflow.keras import datasets, layers, models, regularizers

def cnn_model():
    model = models.Sequential()
    model.add(layers.Conv2D(32, (7,7), strides=(1, 1), padding='same', \
                        activation='relu', input_shape=(32, 32, 1)))
    model.add(layers.BatchNormalization(axis=-1))      
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(layers.Dropout(0.2))
    model.add(layers.Conv2D(64, (4, 4), activation='relu'))
    model.add(layers.BatchNormalization(axis=-1))      
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(layers.Dropout(0.2))
    model.add(layers.Flatten())
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(l=0.05)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(43, activation='softmax'))
    return model

# %%
model = cnn_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        1600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        32832
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 13, 13, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2304)              9216
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                22059
# =================================================================
# Total params: 1,248,299
# Trainable params: 1,242,475
# Non-trainable params: 5,824
# _________________________________________________________________

# %%
---

## Step 5: Train, Validate and Test the Model

# %%
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint

batch_size = 128
epochs = 100

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

lr = 0.01
def lr_schedule(epoch):
    return lr * (0.1 ** int(epoch / 10))

history = model.fit(X_train_normalized, y_train, batch_size=batch_size, epochs=epochs, 
                    validation_data=(X_valid_normalized, y_valid),
                    callbacks=[LearningRateScheduler(lr_schedule), ModelCheckpoint('model.h5', save_best_only=True)])
# Out:
# Train on 150500 samples, validate on 4410 samples
# Epoch 1/100
# 150500/150500 [==============================] - 432s 3ms/sample - loss: 8.3500 - accuracy: 0.7073 - val_loss: 5.0944 - val_accuracy: 0.8615
# Epoch 2/100
# 150500/150500 [==============================] - 429s 3ms/sample - loss: 4.9380 - accuracy: 0.7858 - val_loss: 3.8000 - val_accuracy: 0.9261
# Epoch 3/100
# 150500/150500 [==============================] - 430s 3ms/sample - loss: 3.8915 - accuracy: 0.8069 - val_loss: 3.2999 - val_accuracy: 0.9179
# Epoch 4/100
# 150500/150500 [==============================] - 430s 3ms/sample - loss: 3.3811 - accuracy: 0.8178 - val_loss: 2.9846 - val_accuracy: 0.9390
# Epoch 5/100
# 150500/150500 [==============================] - 430s 3ms/sample - loss: 3.0610 - accuracy: 0.8263 - val_loss: 2.6555 - val_accuracy: 0.9322
# Epoch 6/100
# 150500/150500 [==============================] - 429s 3ms/sample - loss: 2.8700 - accuracy: 0.8338 - val_loss: 2.4133 - val_accuracy: 0.9440
# Epoch 7/100
# 150500/150500 [==============================] - 435s 3ms/sample - loss: 2.6926 - accuracy: 0.8365 - val_loss: 2.3265 - val_accuracy: 0.9145
# Epoch 8/100
# 150500/150500 [==============================] - 434s 3ms/sample - loss: 2.5836 - accuracy: 0.8416 - val_loss: 2.1054 - val_accuracy: 0.9467
# Epoch 9/100
# 150500/150500 [==============================] - 437s 3ms/sample - loss: 2.5043 - accuracy: 0.8440 - val_loss: 2.0549 - val_accuracy: 0.9426
# Epoch 10/100
# 150500/150500 [==============================] - 443s 3ms/sample - loss: 2.4054 - accuracy: 0.8456 - val_loss: 2.2269 - val_accuracy: 0.9351
# Epoch 11/100
# 150500/150500 [==============================] - 440s 3ms/sample - loss: 0.6813 - accuracy: 0.9217 - val_loss: 0.4877 - val_accuracy: 0.9642
# Epoch 12/100
# 150500/150500 [==============================] - 441s 3ms/sample - loss: 0.5998 - accuracy: 0.9276 - val_loss: 0.4603 - val_accuracy: 0.9633
# Epoch 13/100
# 150500/150500 [==============================] - 441s 3ms/sample - loss: 0.5907 - accuracy: 0.9296 - val_loss: 0.4697 - val_accuracy: 0.9628
# Epoch 14/100
# 150500/150500 [==============================] - 573s 4ms/sample - loss: 0.5808 - accuracy: 0.9329 - val_loss: 0.4629 - val_accuracy: 0.9732
# Epoch 15/100
# 150500/150500 [==============================] - 441s 3ms/sample - loss: 0.5888 - accuracy: 0.9326 - val_loss: 0.4684 - val_accuracy: 0.9644
# Epoch 16/100
# 150500/150500 [==============================] - 440s 3ms/sample - loss: 0.5842 - accuracy: 0.9345 - val_loss: 0.4718 - val_accuracy: 0.9601
# Epoch 17/100
# 150500/150500 [==============================] - 439s 3ms/sample - loss: 0.5843 - accuracy: 0.9349 - val_loss: 0.5029 - val_accuracy: 0.9624
# Epoch 18/100
# 150500/150500 [==============================] - 438s 3ms/sample - loss: 0.5916 - accuracy: 0.9354 - val_loss: 0.4640 - val_accuracy: 0.9741
# Epoch 19/100
# 150500/150500 [==============================] - 437s 3ms/sample - loss: 0.5851 - accuracy: 0.9373 - val_loss: 0.4955 - val_accuracy: 0.9551
# Epoch 20/100
# 150500/150500 [==============================] - 443s 3ms/sample - loss: 0.5903 - accuracy: 0.9368 - val_loss: 0.5047 - val_accuracy: 0.9701
# Epoch 21/100
# 150500/150500 [==============================] - 443s 3ms/sample - loss: 0.3244 - accuracy: 0.9572 - val_loss: 0.2091 - val_accuracy: 0.9662
# Epoch 22/100
# 150500/150500 [==============================] - 442s 3ms/sample - loss: 0.2157 - accuracy: 0.9633 - val_loss: 0.1913 - val_accuracy: 0.9687
# Epoch 23/100
# 150500/150500 [==============================] - 443s 3ms/sample - loss: 0.2033 - accuracy: 0.9635 - val_loss: 0.1973 - val_accuracy: 0.9637
# Epoch 24/100
# 150500/150500 [==============================] - 443s 3ms/sample - loss: 0.1974 - accuracy: 0.9644 - val_loss: 0.1867 - val_accuracy: 0.9683
# Epoch 25/100
# 150500/150500 [==============================] - 443s 3ms/sample - loss: 0.1962 - accuracy: 0.9643 - val_loss: 0.1784 - val_accuracy: 0.9678
# Epoch 26/100
# 150500/150500 [==============================] - 442s 3ms/sample - loss: 0.1939 - accuracy: 0.9649 - val_loss: 0.1700 - val_accuracy: 0.9712
# Epoch 27/100
# 150500/150500 [==============================] - 441s 3ms/sample - loss: 0.1920 - accuracy: 0.9650 - val_loss: 0.1844 - val_accuracy: 0.9667
# Epoch 28/100
# 150500/150500 [==============================] - 439s 3ms/sample - loss: 0.1930 - accuracy: 0.9649 - val_loss: 0.1719 - val_accuracy: 0.9698
# Epoch 29/100
# 150500/150500 [==============================] - 439s 3ms/sample - loss: 0.1941 - accuracy: 0.9651 - val_loss: 0.1737 - val_accuracy: 0.9710
# Epoch 30/100
# 150500/150500 [==============================] - 441s 3ms/sample - loss: 0.1941 - accuracy: 0.9652 - val_loss: 0.1953 - val_accuracy: 0.9698
# Epoch 31/100
# 150500/150500 [==============================] - 439s 3ms/sample - loss: 0.1764 - accuracy: 0.9684 - val_loss: 0.1732 - val_accuracy: 0.9712
# Epoch 32/100
# 150500/150500 [==============================] - 440s 3ms/sample - loss: 0.1602 - accuracy: 0.9705 - val_loss: 0.1660 - val_accuracy: 0.9710
# Epoch 33/100
# 150500/150500 [==============================] - 442s 3ms/sample - loss: 0.1476 - accuracy: 0.9721 - val_loss: 0.1586 - val_accuracy: 0.9710
# Epoch 34/100
# 150500/150500 [==============================] - 441s 3ms/sample - loss: 0.1377 - accuracy: 0.9733 - val_loss: 0.1510 - val_accuracy: 0.9710
# Epoch 35/100
# 150500/150500 [==============================] - 445s 3ms/sample - loss: 0.1320 - accuracy: 0.9739 - val_loss: 0.1513 - val_accuracy: 0.9703
# Epoch 36/100
# 150500/150500 [==============================] - 445s 3ms/sample - loss: 0.1266 - accuracy: 0.9740 - val_loss: 0.1482 - val_accuracy: 0.9687
# Epoch 37/100
# 150500/150500 [==============================] - 442s 3ms/sample - loss: 0.1239 - accuracy: 0.9742 - val_loss: 0.1390 - val_accuracy: 0.9701
# Epoch 38/100
# 150500/150500 [==============================] - 444s 3ms/sample - loss: 0.1220 - accuracy: 0.9742 - val_loss: 0.1397 - val_accuracy: 0.9703
# Epoch 39/100
# 150500/150500 [==============================] - 443s 3ms/sample - loss: 0.1158 - accuracy: 0.9755 - val_loss: 0.1384 - val_accuracy: 0.9703
# Epoch 40/100
# 150500/150500 [==============================] - 1929s 13ms/sample - loss: 0.1146 - accuracy: 0.9753 - val_loss: 0.1393 - val_accuracy: 0.9687
# Epoch 41/100
# 150500/150500 [==============================] - 450s 3ms/sample - loss: 0.1126 - accuracy: 0.9757 - val_loss: 0.1355 - val_accuracy: 0.9696
# Epoch 42/100
# 150500/150500 [==============================] - 450s 3ms/sample - loss: 0.1109 - accuracy: 0.9758 - val_loss: 0.1363 - val_accuracy: 0.9689
# Epoch 43/100
# 150500/150500 [==============================] - 449s 3ms/sample - loss: 0.1103 - accuracy: 0.9760 - val_loss: 0.1360 - val_accuracy: 0.9692
# Epoch 44/100
# 150500/150500 [==============================] - 449s 3ms/sample - loss: 0.1104 - accuracy: 0.9759 - val_loss: 0.1360 - val_accuracy: 0.9692
# Epoch 45/100
# 150500/150500 [==============================] - 448s 3ms/sample - loss: 0.1100 - accuracy: 0.9761 - val_loss: 0.1365 - val_accuracy: 0.9696
# Epoch 46/100
# 150500/150500 [==============================] - 445s 3ms/sample - loss: 0.1089 - accuracy: 0.9761 - val_loss: 0.1339 - val_accuracy: 0.9696
# Epoch 47/100
# 150500/150500 [==============================] - 446s 3ms/sample - loss: 0.1091 - accuracy: 0.9758 - val_loss: 0.1352 - val_accuracy: 0.9692
# Epoch 48/100
# 150500/150500 [==============================] - 447s 3ms/sample - loss: 0.1090 - accuracy: 0.9758 - val_loss: 0.1360 - val_accuracy: 0.9692
# Epoch 49/100
# 150500/150500 [==============================] - 446s 3ms/sample - loss: 0.1083 - accuracy: 0.9764 - val_loss: 0.1351 - val_accuracy: 0.9694
# Epoch 50/100
# 150500/150500 [==============================] - 445s 3ms/sample - loss: 0.1081 - accuracy: 0.9764 - val_loss: 0.1350 - val_accuracy: 0.9694
# Epoch 51/100
# 150500/150500 [==============================] - 445s 3ms/sample - loss: 0.1080 - accuracy: 0.9759 - val_loss: 0.1347 - val_accuracy: 0.9692
# Epoch 52/100
# 150500/150500 [==============================] - 445s 3ms/sample - loss: 0.1079 - accuracy: 0.9768 - val_loss: 0.1333 - val_accuracy: 0.9698
# Epoch 53/100
# 150500/150500 [==============================] - 446s 3ms/sample - loss: 0.1081 - accuracy: 0.9763 - val_loss: 0.1332 - val_accuracy: 0.9698
# Epoch 54/100
# 150500/150500 [==============================] - 428s 3ms/sample - loss: 0.1067 - accuracy: 0.9762 - val_loss: 0.1343 - val_accuracy: 0.9692
# Epoch 55/100
# 150500/150500 [==============================] - 428s 3ms/sample - loss: 0.1069 - accuracy: 0.9762 - val_loss: 0.1314 - val_accuracy: 0.9701
# Epoch 56/100
# 150500/150500 [==============================] - 428s 3ms/sample - loss: 0.1070 - accuracy: 0.9763 - val_loss: 0.1342 - val_accuracy: 0.9696
# Epoch 57/100
# 150500/150500 [==============================] - 428s 3ms/sample - loss: 0.1078 - accuracy: 0.9764 - val_loss: 0.1315 - val_accuracy: 0.9698
# Epoch 58/100
# 150500/150500 [==============================] - 427s 3ms/sample - loss: 0.1067 - accuracy: 0.9764 - val_loss: 0.1327 - val_accuracy: 0.9698
# Epoch 59/100
# 150500/150500 [==============================] - 428s 3ms/sample - loss: 0.1055 - accuracy: 0.9767 - val_loss: 0.1333 - val_accuracy: 0.9698
# Epoch 60/100
# 150500/150500 [==============================] - 428s 3ms/sample - loss: 0.1068 - accuracy: 0.9765 - val_loss: 0.1333 - val_accuracy: 0.9696
# Epoch 61/100
# 150500/150500 [==============================] - 428s 3ms/sample - loss: 0.1067 - accuracy: 0.9763 - val_loss: 0.1328 - val_accuracy: 0.9696
# Epoch 62/100
# 150500/150500 [==============================] - 428s 3ms/sample - loss: 0.1050 - accuracy: 0.9768 - val_loss: 0.1329 - val_accuracy: 0.9696
# Epoch 63/100
# 150500/150500 [==============================] - 428s 3ms/sample - loss: 0.1060 - accuracy: 0.9767 - val_loss: 0.1319 - val_accuracy: 0.9698
# Epoch 64/100
# 150500/150500 [==============================] - 429s 3ms/sample - loss: 0.1059 - accuracy: 0.9765 - val_loss: 0.1331 - val_accuracy: 0.9696
# Epoch 65/100
# 150500/150500 [==============================] - 428s 3ms/sample - loss: 0.1066 - accuracy: 0.9765 - val_loss: 0.1332 - val_accuracy: 0.9696
# Epoch 66/100
# 150500/150500 [==============================] - 430s 3ms/sample - loss: 0.1059 - accuracy: 0.9767 - val_loss: 0.1334 - val_accuracy: 0.9696
# Epoch 67/100
# 150500/150500 [==============================] - 433s 3ms/sample - loss: 0.1075 - accuracy: 0.9762 - val_loss: 0.1319 - val_accuracy: 0.9698
# Epoch 68/100
# 150500/150500 [==============================] - 431s 3ms/sample - loss: 0.1070 - accuracy: 0.9772 - val_loss: 0.1324 - val_accuracy: 0.9701
# Epoch 69/100
# 150500/150500 [==============================] - 432s 3ms/sample - loss: 0.1084 - accuracy: 0.9762 - val_loss: 0.1340 - val_accuracy: 0.9696
# Epoch 70/100
# 150500/150500 [==============================] - 448s 3ms/sample - loss: 0.1088 - accuracy: 0.9759 - val_loss: 0.1341 - val_accuracy: 0.9696
# Epoch 71/100
# 150500/150500 [==============================] - 448s 3ms/sample - loss: 0.1061 - accuracy: 0.9765 - val_loss: 0.1315 - val_accuracy: 0.9698
# Epoch 72/100
# 150500/150500 [==============================] - 436s 3ms/sample - loss: 0.1075 - accuracy: 0.9761 - val_loss: 0.1325 - val_accuracy: 0.9698
# Epoch 73/100
# 150500/150500 [==============================] - 436s 3ms/sample - loss: 0.1053 - accuracy: 0.9769 - val_loss: 0.1347 - val_accuracy: 0.9694
# Epoch 74/100
# 150500/150500 [==============================] - 433s 3ms/sample - loss: 0.1060 - accuracy: 0.9771 - val_loss: 0.1332 - val_accuracy: 0.9696
# Epoch 75/100
# 150500/150500 [==============================] - 433s 3ms/sample - loss: 0.1072 - accuracy: 0.9763 - val_loss: 0.1336 - val_accuracy: 0.9696
# Epoch 76/100
# 150500/150500 [==============================] - 435s 3ms/sample - loss: 0.1066 - accuracy: 0.9765 - val_loss: 0.1337 - val_accuracy: 0.9698
# Epoch 77/100
# 150500/150500 [==============================] - 434s 3ms/sample - loss: 0.1076 - accuracy: 0.9759 - val_loss: 0.1326 - val_accuracy: 0.9698
# Epoch 78/100
# 150500/150500 [==============================] - 443s 3ms/sample - loss: 0.1068 - accuracy: 0.9766 - val_loss: 0.1317 - val_accuracy: 0.9698
# Epoch 79/100
# 150500/150500 [==============================] - 434s 3ms/sample - loss: 0.1075 - accuracy: 0.9762 - val_loss: 0.1332 - val_accuracy: 0.9696
# Epoch 80/100
# 150500/150500 [==============================] - 433s 3ms/sample - loss: 0.1065 - accuracy: 0.9769 - val_loss: 0.1317 - val_accuracy: 0.9701
# Epoch 81/100
# 150500/150500 [==============================] - 433s 3ms/sample - loss: 0.1077 - accuracy: 0.9762 - val_loss: 0.1333 - val_accuracy: 0.9694
# Epoch 82/100
# 150500/150500 [==============================] - 433s 3ms/sample - loss: 0.1067 - accuracy: 0.9762 - val_loss: 0.1340 - val_accuracy: 0.9694
# Epoch 83/100
# 150500/150500 [==============================] - 434s 3ms/sample - loss: 0.1078 - accuracy: 0.9760 - val_loss: 0.1334 - val_accuracy: 0.9694
# Epoch 84/100
# 150500/150500 [==============================] - 433s 3ms/sample - loss: 0.1080 - accuracy: 0.9760 - val_loss: 0.1334 - val_accuracy: 0.9696
# Epoch 85/100
# 150500/150500 [==============================] - 433s 3ms/sample - loss: 0.1077 - accuracy: 0.9761 - val_loss: 0.1321 - val_accuracy: 0.9698
# Epoch 86/100
# 150500/150500 [==============================] - 432s 3ms/sample - loss: 0.1056 - accuracy: 0.9768 - val_loss: 0.1323 - val_accuracy: 0.9698
# Epoch 87/100
# 150500/150500 [==============================] - 437s 3ms/sample - loss: 0.1070 - accuracy: 0.9766 - val_loss: 0.1333 - val_accuracy: 0.9698
# Epoch 88/100
# 150500/150500 [==============================] - 438s 3ms/sample - loss: 0.1073 - accuracy: 0.9765 - val_loss: 0.1332 - val_accuracy: 0.9696
# Epoch 89/100
# 150500/150500 [==============================] - 438s 3ms/sample - loss: 0.1063 - accuracy: 0.9763 - val_loss: 0.1339 - val_accuracy: 0.9698
# Epoch 90/100
# 150500/150500 [==============================] - 439s 3ms/sample - loss: 0.1079 - accuracy: 0.9759 - val_loss: 0.1339 - val_accuracy: 0.9692
# Epoch 91/100
# 150500/150500 [==============================] - 445s 3ms/sample - loss: 0.1081 - accuracy: 0.9759 - val_loss: 0.1322 - val_accuracy: 0.9698
# Epoch 92/100
# 150500/150500 [==============================] - 439s 3ms/sample - loss: 0.1070 - accuracy: 0.9763 - val_loss: 0.1321 - val_accuracy: 0.9701
# Epoch 93/100
# 150500/150500 [==============================] - 442s 3ms/sample - loss: 0.1072 - accuracy: 0.9770 - val_loss: 0.1342 - val_accuracy: 0.9692
# Epoch 94/100
# 150500/150500 [==============================] - 442s 3ms/sample - loss: 0.1077 - accuracy: 0.9762 - val_loss: 0.1333 - val_accuracy: 0.9696
# Epoch 95/100
# 150500/150500 [==============================] - 445s 3ms/sample - loss: 0.1066 - accuracy: 0.9768 - val_loss: 0.1331 - val_accuracy: 0.9698
# Epoch 96/100
# 150500/150500 [==============================] - 445s 3ms/sample - loss: 0.1062 - accuracy: 0.9767 - val_loss: 0.1350 - val_accuracy: 0.9692
# Epoch 97/100
# 150500/150500 [==============================] - 444s 3ms/sample - loss: 0.1066 - accuracy: 0.9765 - val_loss: 0.1338 - val_accuracy: 0.9696
# Epoch 98/100
# 150500/150500 [==============================] - 436s 3ms/sample - loss: 0.1076 - accuracy: 0.9762 - val_loss: 0.1324 - val_accuracy: 0.9698
# Epoch 99/100
# 150500/150500 [==============================] - 437s 3ms/sample - loss: 0.1069 - accuracy: 0.9763 - val_loss: 0.1343 - val_accuracy: 0.9696
# Epoch 100/100
# 150500/150500 [==============================] - 436s 3ms/sample - loss: 0.1085 - accuracy: 0.9762 - val_loss: 0.1340 - val_accuracy: 0.9692

# %% [markdown]
# ### Plot Training Performance

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %% [markdown]
# ### Load Best Model

# %%
import tensorflow as tf
model = tf.keras.models.load_model(
    'model/model.h5',
    custom_objects=None,
    compile=True
)

# %% [markdown]
# ### Evaluate on Test Set

# %%
from sklearn.utils import shuffle
X_test, y_test = shuffle(X_test, y_test)

X_test_temp = []

for img in X_test:
    X_test_temp.append(equalize_hist(img))

X_test_normalized = normalize_data(np.array(X_test_temp))

# %%
test_loss, test_acc = model.evaluate(X_test_normalized,  y_test, verbose=2)
print("test: ", test_acc)
# Out:
# 34799/1 - 23s - loss: 0.0771 - accuracy: 0.9734
# test:  0.9733613

# %%
X_test_slice = np.array(X_test_normalized[0:5])

class_prob=model.predict(X_test_slice,batch_size=1)
classifications=model.predict_classes(X_test_slice,batch_size=1)

print(np.amax(class_prob[0]))
print(classifications[0])
plt.imshow(X_test[0], cmap="gray")
plt.show()

print(np.amax(class_prob[1]))
print(classifications[1])
plt.imshow(X_test[1], cmap="gray")
plt.show()

print(np.amax(class_prob[2]))
print(classifications[2])
plt.imshow(X_test[2], cmap="gray")
plt.show()

print(np.amax(class_prob[3]))
print(classifications[3])
plt.imshow(X_test[3], cmap="gray")
plt.show()

print(np.amax(class_prob[4]))
print(classifications[4])
plt.imshow(X_test[4], cmap="gray")
plt.show()
# Out:
# 1.0
# 4
# 0.9997141
# 4
# 0.999387
# 9
# 1.0
# 2
# 0.9997727
# 36

# %% [markdown]
# ---
#
# ## Step 6: Test Model on New Images
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name. The python dictionary `sign_id_dict` contains the content of this csv file.

# %% [markdown]
# ### Helper Functions and Constants

# %%
dim = (32, 32)
num_correct_classified = 0
num_new_images = 0

def process_img(img, correct_class):
    global dim
    resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    plt.imshow(resized)
    plt.show()

    resized = [resized]
    resized = normalize_data(np.array(resized))
    class_prob=model.predict(resized,batch_size=1)
    top_three_pred = np.argsort(class_prob[0])[-5:][::-1]
    print_top_five(top_three_pred, class_prob)

    classifications=model.predict_classes(resized,batch_size=1)

    global num_new_images, num_correct_classified
    num_new_images += 1
    if classifications[0] == correct_class:
        num_correct_classified += 1
    
    print('Predicted traffic sign: ', sign_id_dict[str(classifications[0])])

def print_top_five(top_three_pred, class_prob):
    print("--- Top 5 class probabilities --- ")
    print("Class ", top_three_pred[0], ": ", class_prob[0][top_three_pred[0]])
    print("Class ", top_three_pred[1], ": ", class_prob[0][top_three_pred[1]])
    print("Class ", top_three_pred[2], ": ", class_prob[0][top_three_pred[2]])
    print("Class ", top_three_pred[3], ": ", class_prob[0][top_three_pred[3]])
    print("Class ", top_three_pred[4], ": ", class_prob[0][top_three_pred[4]])
    print()

# %% [markdown]
# ### Perform Predictions on New Images

# %%
test_img = plt.imread('./new-test-images/test1.jpg')
plt.imshow(test_img)
plt.show()

process_img(test_img, 33)
# Out:
# --- Top 5 class probabilities ---
# Class  33 :  0.99999976
# Class  39 :  1.6237857e-07
# Class  42 :  1.2753995e-07
# Class  16 :  4.4880064e-09
# Class  32 :  4.079194e-10
#
# Predicted traffic sign:  Turn right ahead

# %%
test_img = plt.imread('./new-test-images/test2.jpg')

plt.imshow(test_img)
plt.show()

process_img(test_img, 35)
# Out:
# --- Top 5 class probabilities ---
# Class  35 :  0.99507445
# Class  37 :  0.0031295284
# Class  33 :  0.0012267178
# Class  39 :  0.00014617901
# Class  13 :  0.00014540403
#
# Predicted traffic sign:  Ahead only

# %%
test_img = plt.imread('./new-test-images/test3.jpg')
plt.imshow(test_img)
plt.show()

process_img(test_img, 37)
# Out:
# --- Top 5 class probabilities ---
# Class  37 :  0.6686111
# Class  34 :  0.15958273
# Class  35 :  0.15163164
# Class  22 :  0.0058902674
# Class  33 :  0.0044864267
#
# Predicted traffic sign:  Go straight or left

# %%
test_img = plt.imread('./new-test-images/test4.jpg')
plt.imshow(test_img)
plt.show()

process_img(test_img, 28)
# Out:
# --- Top 5 class probabilities ---
# Class  28 :  0.47121543
# Class  24 :  0.19781165
# Class  18 :  0.10108695
# Class  30 :  0.08471906
# Class  29 :  0.08393768
#
# Predicted traffic sign:  Children crossing

# %%
test_img = plt.imread('./new-test-images/test5.jpg')
plt.imshow(test_img)
plt.show()

process_img(test_img, 17)
# Out:
# --- Top 5 class probabilities ---
# Class  17 :  0.9355764
# Class  10 :  0.023313014
# Class  38 :  0.016573582
# Class  9 :  0.0077320533
# Class  14 :  0.0031665745
#
# Predicted traffic sign:  No entry

# %%
test_img = plt.imread('./new-test-images/test6.jpg')
plt.imshow(test_img)
plt.show()

process_img(test_img, 8)
# Out:
# --- Top 5 class probabilities ---
# Class  8 :  0.3654121
# Class  5 :  0.17612468
# Class  7 :  0.1394114
# Class  2 :  0.13234085
# Class  3 :  0.12925556
#
# Predicted traffic sign:  Speed limit (120km/h)

# %% [markdown]
# ### Analyze Performance

# %%
print("Percentage correctly classified on new images: ", (num_correct_classified/num_new_images)*100, "%")
# Out:
# Percentage correctly classified on new images:  100.0 %
